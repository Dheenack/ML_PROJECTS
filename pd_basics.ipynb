# %%
import pandas as pd

# %%
df=pd.read_csv("Personal_Finance_Dataset.csv")

# %%
df.head(10)
# Out:
#          Date                    Transaction Description       Category  \
# 0  2020-01-02                                Score each.   Food & Drink
# 1  2020-01-02                        Quality throughout.      Utilities
# 2  2020-01-04         Instead ahead despite measure ago.           Rent
# 3  2020-01-05   Information last everything thank serve.     Investment
# 4  2020-01-13               Future choice whatever from.   Food & Drink
# 5  2020-01-14             Benefit suggest page southern.       Shopping
# 6  2020-01-18                      By two bad fall pick.   Food & Drink
# 7  2020-01-19  Court attorney product significant world.          Other
# 8  2020-01-21                               Herself law.  Entertainment
# 9  2020-01-25                   Have decide environment.           Rent
#
#     Amount     Type
# 0  1485.69  Expense
# 1  1475.58  Expense
# 2  1185.08  Expense
# 3  2291.00   Income
# 4  1126.88  Expense
# 5   448.68  Expense
# 6  1520.03  Expense
# ...

# %%
df.tail(10)
# Out:
#             Date                        Transaction Description  \
# 1490  2024-12-16                          Child group describe.
# 1491  2024-12-19  Democratic recent student specific political.
# 1492  2024-12-19                             Real know our any.
# 1493  2024-12-21                                  Up hear draw.
# 1494  2024-12-23                                Instead writer.
# 1495  2024-12-28                                 Quite as when.
# 1496  2024-12-28                        Right analysis mention.
# 1497  2024-12-28                         No couple debate must.
# 1498  2024-12-29                       Discussion black follow.
# 1499  2024-12-29              Pressure activity defense detail.
#
#               Category   Amount     Type
# 1490          Shopping  1544.74  Expense
# 1491      Food & Drink   406.37  Expense
# 1492              Rent  1047.07  Expense
# 1493            Salary   784.35  Expense
# 1494  Health & Fitness   325.64  Expense
# ...

# %%
df.shape
# Out:
# (1500, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1500, step=1)

# %%
df.columns
# Out:
# Index(['Date', 'Transaction Description', 'Category', 'Amount', 'Type'], dtype='object')

# %%
df1=df.drop(1,axis=0)
df1.head()
# Out:
#          Date                   Transaction Description      Category  \
# 0  2020-01-02                               Score each.  Food & Drink
# 2  2020-01-04        Instead ahead despite measure ago.          Rent
# 3  2020-01-05  Information last everything thank serve.    Investment
# 4  2020-01-13              Future choice whatever from.  Food & Drink
# 5  2020-01-14            Benefit suggest page southern.      Shopping
#
#     Amount     Type
# 0  1485.69  Expense
# 2  1185.08  Expense
# 3  2291.00   Income
# 4  1126.88  Expense
# 5   448.68  Expense

# %%
sorted=df1.sort_values(by="Amount")
sorted.head()
# Out:
#             Date         Transaction Description       Category  Amount  \
# 1195  2023-12-29      Society dark product make.  Entertainment   14.37
# 231   2020-10-29  Office of remember individual.      Utilities   15.32
# 1150  2023-11-09               What strong line.  Entertainment   15.45
# 1121  2023-10-03               Strong mind from.       Shopping   19.29
# 1294  2024-04-20           Skill successful and.      Utilities   19.62
#
#          Type
# 1195  Expense
# 231   Expense
# 1150  Expense
# 1121  Expense
# 1294  Expense

# %%
ranked=df1["Amount"].rank(method='min')
ranked.head()
# Out:
# 0     983.0
# 2     774.0
# 3    1331.0
# 4     738.0
# 5     268.0
# Name: Amount, dtype: float64

# %%
df1.dropna()
# Out:
#             Date                   Transaction Description       Category  \
# 0     2020-01-02                               Score each.   Food & Drink
# 2     2020-01-04        Instead ahead despite measure ago.           Rent
# 3     2020-01-05  Information last everything thank serve.     Investment
# 4     2020-01-13              Future choice whatever from.   Food & Drink
# 5     2020-01-14            Benefit suggest page southern.       Shopping
# ...          ...                                       ...            ...
# 1495  2024-12-28                            Quite as when.           Rent
# 1496  2024-12-28                   Right analysis mention.  Entertainment
# 1497  2024-12-28                    No couple debate must.     Investment
# 1498  2024-12-29                  Discussion black follow.       Shopping
# 1499  2024-12-29         Pressure activity defense detail.          Other
#
#        Amount     Type
# 0     1485.69  Expense
# 2     1185.08  Expense
# ...

# %%
df1.fillna("a")
# Out:
#             Date                   Transaction Description       Category  \
# 0     2020-01-02                               Score each.   Food & Drink
# 2     2020-01-04        Instead ahead despite measure ago.           Rent
# 3     2020-01-05  Information last everything thank serve.     Investment
# 4     2020-01-13              Future choice whatever from.   Food & Drink
# 5     2020-01-14            Benefit suggest page southern.       Shopping
# ...          ...                                       ...            ...
# 1495  2024-12-28                            Quite as when.           Rent
# 1496  2024-12-28                   Right analysis mention.  Entertainment
# 1497  2024-12-28                    No couple debate must.     Investment
# 1498  2024-12-29                  Discussion black follow.       Shopping
# 1499  2024-12-29         Pressure activity defense detail.          Other
#
#        Amount     Type
# 0     1485.69  Expense
# 2     1185.08  Expense
# ...

# %%
df.isnull()
# Out:
#        Date  Transaction Description  Category  Amount   Type
# 0     False                    False     False   False  False
# 1     False                    False     False   False  False
# 2     False                    False     False   False  False
# 3     False                    False     False   False  False
# 4     False                    False     False   False  False
# ...     ...                      ...       ...     ...    ...
# 1495  False                    False     False   False  False
# 1496  False                    False     False   False  False
# 1497  False                    False     False   False  False
# 1498  False                    False     False   False  False
# 1499  False                    False     False   False  False
#
# [1500 rows x 5 columns]

# %%
df.notnull()
# Out:
#       Date  Transaction Description  Category  Amount  Type
# 0     True                     True      True    True  True
# 1     True                     True      True    True  True
# 2     True                     True      True    True  True
# 3     True                     True      True    True  True
# 4     True                     True      True    True  True
# ...    ...                      ...       ...     ...   ...
# 1495  True                     True      True    True  True
# 1496  True                     True      True    True  True
# 1497  True                     True      True    True  True
# 1498  True                     True      True    True  True
# 1499  True                     True      True    True  True
#
# [1500 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1500 non-null   object
#  1   Transaction Description  1500 non-null   object
#  2   Category                 1500 non-null   object
#  3   Amount                   1500 non-null   float64
#  4   Type                     1500 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 58.7+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Transaction Description', 'Category', 'Amount', 'Type'], dtype='object')

# %%
df.count()
# Out:
# Date                       1500
# Transaction Description    1500
# Category                   1500
# Amount                     1500
# Type                       1500
# dtype: int64

# %%
df["Date"].unique
# Out:
# <bound method Series.unique of 0       2020-01-02
# 1       2020-01-02
# 2       2020-01-04
# 3       2020-01-05
# 4       2020-01-13
#            ...
# 1495    2024-12-28
# 1496    2024-12-28
# 1497    2024-12-28
# 1498    2024-12-29
# 1499    2024-12-29
# Name: Date, Length: 1500, dtype: object>

# %%
df1.head()
# Out:
#          Date                   Transaction Description      Category  \
# 0  2020-01-02                               Score each.  Food & Drink
# 2  2020-01-04        Instead ahead despite measure ago.          Rent
# 3  2020-01-05  Information last everything thank serve.    Investment
# 4  2020-01-13              Future choice whatever from.  Food & Drink
# 5  2020-01-14            Benefit suggest page southern.      Shopping
#
#     Amount     Type
# 0  1485.69  Expense
# 2  1185.08  Expense
# 3  2291.00   Income
# 4  1126.88  Expense
# 5   448.68  Expense

# %%
df1.columns.values[0]="date"
df1.head()
# Out:
#          date                   Transaction Description      Category  \
# 0  2020-01-02                               Score each.  Food & Drink
# 2  2020-01-04        Instead ahead despite measure ago.          Rent
# 3  2020-01-05  Information last everything thank serve.    Investment
# 4  2020-01-13              Future choice whatever from.  Food & Drink
# 5  2020-01-14            Benefit suggest page southern.      Shopping
#
#     Amount     Type
# 0  1485.69  Expense
# 2  1185.08  Expense
# 3  2291.00   Income
# 4  1126.88  Expense
# 5   448.68  Expense
